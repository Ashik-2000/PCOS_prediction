# %%
# 0 = No
# 1 = Yes

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.feature_selection import mutual_info_classif
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import AdaBoostClassifier


from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, roc_curve, roc_auc_score, auc

from sklearn import preprocessing

# %%
data = pd.read_csv('PCOS_Final_Data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              541 non-null    int64
#  1   Sl. No                  541 non-null    int64
#  2   Patient File No.        541 non-null    int64
#  3   PCOS (Y/N)              541 non-null    int64
#  4    Age (yrs)              541 non-null    int64
#  5   Weight (Kg)             541 non-null    float64
#  6   Height(Cm)              541 non-null    float64
#  7   BMI                     541 non-null    float64
#  8   Blood Group             541 non-null    int64
#  9   Pulse rate(bpm)         541 non-null    int64
#  10  RR (breaths/min)        541 non-null    int64
#  11  Hb(g/dl)                541 non-null    float64
#  12  Cycle(R/I)              541 non-null    int64
#  13  Cycle length(days)      541 non-null    int64
# ...

# %%
#There is a column without name,So, first naming it.
data = data.rename(columns={'Unnamed: 0': 'index'})

# %%
#Droping the columns which are not related to the output
data = data.drop(['index','Sl. No','Patient File No.'],axis=1)

# %%
data.head()
# Out:
#    PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)         BMI  Blood Group  \
# 0           0          28         44.6        152.0  19.300000           15
# 1           0          36         65.0        161.5  24.921163           15
# 2           1          33         68.8        165.0  25.270891           11
# 3           0          37         65.0        148.0  29.674945           13
# 4           0          25         52.0        161.0  20.060954           11
#
#    Pulse rate(bpm)   RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  ...  \
# 0                78                22     10.48           2  ...
# 1                74                20     11.70           2  ...
# 2                72                18     11.80           2  ...
# 3                72                20     12.00           2  ...
# 4                72                18     10.00           2  ...
#
#    Reg.Exercise(Y/N)  BP _Systolic (mmHg)  BP _Diastolic (mmHg)  \
# ...

# %%
# Separate the features (X) and the target variable (y)
X = data.drop(columns='PCOS (Y/N)')  
y = data['PCOS (Y/N)']

# %% [markdown]
# # Applying Mutual info for finding better features from the dataset

# %%
# Compute mutual information between each feature and the target variable
mutual_info = mutual_info_classif(X, y)

# %%
# Create a DataFrame to store feature names and their corresponding mutual information scores
mi_scores = pd.Series(mutual_info, index=X.columns).sort_values(ascending=False)

# Print the mutual information scores for each feature
mi_scores
# Out:
# Follicle No. (R)          0.235879
# Follicle No. (L)          0.211265
# Weight gain(Y/N)          0.124493
# Skin darkening (Y/N)      0.109064
# hair growth(Y/N)          0.101399
# Cycle length(days)        0.098096
# Fast food (Y/N)           0.091176
# Cycle(R/I)                0.076042
# AMH(ng/mL)                0.068612
# FSH/LH                    0.066738
# PRL(ng/mL)                0.063405
# Hip(inch)                 0.027017
# Hair loss(Y/N)            0.026173
# Waist(inch)               0.025657
# LH(mIU/mL)                0.024754
# TSH (mIU/L)               0.024451
# Pimples(Y/N)              0.024285
# FSH(mIU/mL)               0.022911
# Weight (Kg)               0.019041
# Hb(g/dl)                  0.017921
# PRG(ng/mL)                0.017257
# Vit D3 (ng/mL)            0.016385
# No. of aborptions         0.014305
#   I   beta-HCG(mIU/mL)    0.011583
# Pulse rate(bpm)           0.009466
# BMI                       0.007896
# Avg. F size (L) (mm)      0.007560
# ...

# %%
# Splitting the data into training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Standard Scaler applying for better prediction
x_train = preprocessing.StandardScaler().fit_transform(X_train)
x_test = preprocessing.StandardScaler().fit_transform(X_test)

# %% [markdown]
# # Applying Machine Learning Models

# %% [markdown]
# # Logistic Regression

# %%
LR = LogisticRegression(random_state=0)
LR.fit(X_train, y_train)
predictions_LR = LR.predict(X_test)

# Calculate accuracy_LR
accuracy_LR = accuracy_score(y_test, predictions_LR)
print("accuracy_LR:", round(accuracy_LR*100, 2), "%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_LR)
print("\nConfusion Matrix:\n", conf_matrix)

# precision, recall, f1, roc
precision_LR = round(precision_score(y_test,predictions_LR)*100, 2)
recall_LR = round(recall_score(y_test,predictions_LR)*100,2)
f1_LR = round(f1_score(y_test,predictions_LR)*1,2)
roc_LR = round(roc_auc_score(y_test,predictions_LR)*100,2)

print("Precision: ",precision_LR,'%')
print("Recall score: ",recall_LR,'%')
print("F1 Score:", f1_LR)
print("ROC score: ",roc_LR,'%')
# Out:
# accuracy_LR: 84.4 %
#
# Confusion Matrix:
#  [[70  7]
#  [10 22]]
# Precision:  75.86 %
# Recall score:  68.75 %
# F1 Score: 0.72
# ROC score:  79.83 %
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # GaussianNB

# %%
GNB = GaussianNB()
GNB.fit(X_train, y_train)
predictions_GNB = GNB.predict(X_test)

# Calculate accuracy_GNB
accuracy_GNB = accuracy_score(y_test, predictions_GNB)
print("accuracy_GNB:", round(accuracy_GNB*100, 2), "%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_GNB)
print("\nConfusion Matrix:\n", conf_matrix)

# precision, recall, f1, roc
precision_GNB = round(precision_score(y_test,predictions_GNB)*100, 2)
recall_GNB = round(recall_score(y_test,predictions_GNB)*100,2)
f1_GNB = round(f1_score(y_test,predictions_GNB)*1,2)
roc_GNB = round(roc_auc_score(y_test,predictions_GNB)*100,2)

print("Precision: ",precision_GNB,'%')
print("Recall score: ",recall_GNB,'%')
print("F1 Score:", f1_GNB)
print("ROC score: ",roc_GNB,'%')
# Out:
# accuracy_GNB: 80.73 %
#
# Confusion Matrix:
#  [[61 16]
#  [ 5 27]]
# Precision:  62.79 %
# Recall score:  84.38 %
# F1 Score: 0.72
# ROC score:  81.8 %

# %% [markdown]
# # Decision Tree Classifier

# %%
DTC = DecisionTreeClassifier()
DTC.fit(X_train, y_train)
predictions_DTC = DTC.predict(X_test)

# Calculate accuracy_DTC
accuracy_DTC = accuracy_score(y_test, predictions_DTC)
print("accuracy_DTC:", round(accuracy_DTC*100, 2), "%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_DTC)
print("\nConfusion Matrix:\n", conf_matrix)

# precision, recall, f1, roc
precision_DTC = round(precision_score(y_test,predictions_DTC)*100, 2)
recall_DTC = round(recall_score(y_test,predictions_DTC)*100,2)
f1_DTC = round(f1_score(y_test,predictions_DTC)*1,2)
roc_DTC = round(roc_auc_score(y_test,predictions_DTC)*100,2)

print("Precision: ",precision_DTC,'%')
print("Recall score: ",recall_DTC,'%')
print("F1 Score:", f1_DTC)
print("ROC score: ",roc_DTC,'%')
# Out:
# accuracy_DTC: 83.49 %
#
# Confusion Matrix:
#  [[67 10]
#  [ 8 24]]
# Precision:  70.59 %
# Recall score:  75.0 %
# F1 Score: 0.73
# ROC score:  81.01 %

# %% [markdown]
# # Random Forest Classifier

# %%
RFC = RandomForestClassifier()
RFC.fit(X_train, y_train)
predictions_RFC = RFC.predict(X_test)

# Calculate accuracy_RFC
accuracy_RFC = accuracy_score(y_test, predictions_RFC)
print("accuracy_RFC:", round(accuracy_RFC*100, 2), "%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_RFC)
print("\nConfusion Matrix:\n", conf_matrix)

# precision, recall, f1, roc
precision_RFC = round(precision_score(y_test,predictions_RFC)*100, 2)
recall_RFC = round(recall_score(y_test,predictions_RFC)*100,2)
f1_RFC = round(f1_score(y_test,predictions_RFC)*1,2)
roc_RFC = round(roc_auc_score(y_test,predictions_RFC)*100,2)

print("Precision: ",precision_RFC,'%')
print("Recall score: ",recall_RFC,'%')
print("F1 Score:", f1_RFC)
print("ROC score: ",roc_RFC,'%')
# Out:
# accuracy_RFC: 93.58 %
#
# Confusion Matrix:
#  [[76  1]
#  [ 6 26]]
# Precision:  96.3 %
# Recall score:  81.25 %
# F1 Score: 0.88
# ROC score:  89.98 %

# %% [markdown]
# # SVC

# %%
SVC = SVC()
SVC.fit(X_train, y_train)
predictions_SVC = SVC.predict(X_test)

# Calculate accuracy_SVC
accuracy_SVC = accuracy_score(y_test, predictions_SVC)
print("accuracy_SVC:", round(accuracy_SVC*100, 2), "%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_SVC)
print("\nConfusion Matrix:\n", conf_matrix)

# precision, recall, f1, roc
precision_SVC = round(precision_score(y_test,predictions_SVC)*100, 2)
recall_SVC = round(recall_score(y_test,predictions_SVC)*100,2)
f1_SVC = round(f1_score(y_test,predictions_SVC)*1,2)
roc_SVC = round(roc_auc_score(y_test,predictions_SVC)*100,2)
print("Precision: ",precision_SVC,'%')
print("Recall score: ",recall_SVC,'%')
print("F1 Score:", f1_SVC)
print("ROC score: ",roc_SVC,'%')
# Out:
# accuracy_SVC: 71.56 %
#
# Confusion Matrix:
#  [[77  0]
#  [31  1]]
# Precision:  100.0 %
# Recall score:  3.12 %
# F1 Score: 0.06
# ROC score:  51.56 %

# %% [markdown]
# # Multinomial NB

# %%
MNB = MultinomialNB()
MNB.fit(X_train, y_train)
predictions_MNB = MNB.predict(X_test)

# Calculate accuracy_MNB
accuracy_MNB = accuracy_score(y_test, predictions_MNB)
print("accuracy_MNB:", round(accuracy_MNB*100, 2), "%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_MNB)
print("\nConfusion Matrix:\n", conf_matrix)

# precision, recall, f1, roc
precision_MNB = round(precision_score(y_test,predictions_MNB)*100, 2)
recall_MNB = round(recall_score(y_test,predictions_MNB)*100,2)
f1_MNB = round(f1_score(y_test,predictions_MNB)*1,2)
roc_MNB = round(roc_auc_score(y_test,predictions_MNB)*100,2)
print("Precision: ",precision_MNB,'%')
print("Recall score: ",recall_MNB,'%')
print("F1 Score:", f1_MNB)
print("ROC score: ",roc_MNB,'%')
# Out:
# accuracy_MNB: 33.94 %
#
# Confusion Matrix:
#  [[13 64]
#  [ 8 24]]
# Precision:  27.27 %
# Recall score:  75.0 %
# F1 Score: 0.4
# ROC score:  45.94 %

# %% [markdown]
# # MLP Classifier

# %%
MLP = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=1000)
MLP.fit(X_train, y_train)
predictions_MLP = MLP.predict(X_test)

# Calculate accuracy_MLP
accuracy_MLP = accuracy_score(y_test, predictions_MLP)
print("accuracy_MLP:", round(accuracy_MLP*100, 2), "%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_MLP)
print("\nConfusion Matrix:\n", conf_matrix)

# precision, recall, f1, roc
precision_MLP = round(precision_score(y_test,predictions_MLP)*100, 2)
recall_MLP = round(recall_score(y_test,predictions_MLP)*100,2)
f1_MLP = round(f1_score(y_test,predictions_MLP)*1,2)
roc_MLP = round(roc_auc_score(y_test,predictions_MLP)*100,2)

print("Precision: ",precision_MLP,'%')
print("Recall score: ",recall_MLP,'%')
print("F1 Score:", f1_MLP)
print("ROC score: ",roc_MLP,'%')
# Out:
# accuracy_MLP: 72.48 %
#
# Confusion Matrix:
#  [[64 13]
#  [17 15]]
# Precision:  53.57 %
# Recall score:  46.88 %
# F1 Score: 0.5
# ROC score:  65.0 %

# %% [markdown]
# # Linear SVC

# %%
LSVC = LinearSVC()
LSVC.fit(X_train, y_train)
predictions_LSVC = LSVC.predict(X_test)

# Calculate accuracy_LSVC
accuracy_LSVC = accuracy_score(y_test, predictions_LSVC)
print("accuracy_LSVC:", round(accuracy_LSVC*100, 2), "%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_LSVC)
print("\nConfusion Matrix:\n", conf_matrix)

# precision, recall, f1, roc
precision_LSVC = round(precision_score(y_test,predictions_LSVC)*100, 2)
recall_LSVC = round(recall_score(y_test,predictions_LSVC)*100,2)
f1_LSVC = round(f1_score(y_test,predictions_LSVC)*1,2)
roc_LSVC = round(roc_auc_score(y_test,predictions_LSVC)*100,2)

print("Precision: ",precision_LSVC,'%')
print("Recall score: ",recall_LSVC,'%')
print("F1 Score:", f1_LSVC)
print("ROC score: ",roc_LSVC,'%')
# Out:
# accuracy_LSVC: 85.32 %
#
# Confusion Matrix:
#  [[72  5]
#  [11 21]]
# Precision:  80.77 %
# Recall score:  65.62 %
# F1 Score: 0.72
# ROC score:  79.57 %
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# # K Neighbors Classifier

# %%
KNN = KNeighborsClassifier()
KNN.fit(X_train, y_train)
predictions_KNN = KNN.predict(X_test)

# Calculate accuracy_KNN
accuracy_KNN = accuracy_score(y_test, predictions_KNN)
print("accuracy_KNN:", round(accuracy_KNN*100, 2), "%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_KNN)
print("\nConfusion Matrix:\n", conf_matrix)

# precision, recall, f1, roc
precision_KNN = round(precision_score(y_test,predictions_KNN)*100, 2)
recall_KNN = round(recall_score(y_test,predictions_KNN)*100,2)
f1_KNN = round(f1_score(y_test,predictions_KNN)*1,2)
roc_KNN = round(roc_auc_score(y_test,predictions_KNN)*100,2)

print("Precision: ",precision_KNN,'%')
print("Recall score: ",recall_KNN,'%')
print("F1 Score:", f1_KNN)
print("ROC score: ",roc_KNN,'%')
# Out:
# accuracy_KNN: 61.47 %
#
# Confusion Matrix:
#  [[57 20]
#  [22 10]]
# Precision:  33.33 %
# Recall score:  31.25 %
# F1 Score: 0.32
# ROC score:  52.64 %

# %% [markdown]
# # Gradient Boosting

# %%
GBC = GradientBoostingClassifier()
GBC.fit(X_train, y_train)
predictions_GBC = GBC.predict(X_test)

# Calculate accuracy_GBC
accuracy_GBC = accuracy_score(y_test, predictions_GBC)
print("accuracy_GBC:", round(accuracy_GBC*100, 2), "%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_GBC)
print("\nConfusion Matrix:\n", conf_matrix)

# precision, recall, f1, roc
precision_GBC = round(precision_score(y_test,predictions_GBC)*100, 2)
recall_GBC = round(recall_score(y_test,predictions_GBC)*100,2)
f1_GBC = round(f1_score(y_test,predictions_GBC)*1,2)
roc_GBC = round(roc_auc_score(y_test,predictions_GBC)*100,2)

print("Precision: ",precision_GBC,'%')
print("Recall score: ",recall_GBC,'%')
print("F1 Score:", f1_GBC)
print("ROC score: ",roc_GBC,'%')
# Out:
# accuracy_GBC: 91.74 %
#
# Confusion Matrix:
#  [[73  4]
#  [ 5 27]]
# Precision:  87.1 %
# Recall score:  84.38 %
# F1 Score: 0.86
# ROC score:  89.59 %

# %% [markdown]
# # Extra Tree Classifier

# %%
ETC = ExtraTreesClassifier()
ETC.fit(X_train, y_train)
predictions_ETC = ETC.predict(X_test)

# Calculate accuracy_ETC
accuracy_ETC = accuracy_score(y_test, predictions_ETC)
print("accuracy_ETC:", round(accuracy_ETC*100, 2), "%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_ETC)
print("\nConfusion Matrix:\n", conf_matrix)

# precision, recall, f1, roc
precision_ETC = round(precision_score(y_test,predictions_ETC)*100, 2)
recall_ETC = round(recall_score(y_test,predictions_ETC)*100,2)
f1_ETC = round(f1_score(y_test,predictions_ETC)*1,2)
roc_ETC = round(roc_auc_score(y_test,predictions_ETC)*100,2)

print("Precision: ",precision_ETC,'%')
print("Recall score: ",recall_ETC,'%')
print("F1 Score:", f1_ETC)
print("ROC score: ",roc_ETC,'%')
# Out:
# accuracy_ETC: 90.83 %
#
# Confusion Matrix:
#  [[71  6]
#  [ 4 28]]
# Precision:  82.35 %
# Recall score:  87.5 %
# F1 Score: 0.85
# ROC score:  89.85 %

# %% [markdown]
# # BernoulliNB

# %%
BNB = BernoulliNB()
BNB.fit(X_train, y_train)
predictions_BNB = BNB.predict(X_test)

# Calculate accuracy_BNB
accuracy_BNB = accuracy_score(y_test, predictions_BNB)
print("accuracy_BNB:", round(accuracy_BNB*100, 2), "%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_BNB)
print("\nConfusion Matrix:\n", conf_matrix)

# precision, recall, f1, roc
precision_BNB = round(precision_score(y_test,predictions_BNB)*100, 2)
recall_BNB = round(recall_score(y_test,predictions_BNB)*100,2)
f1_BNB = round(f1_score(y_test,predictions_BNB)*1,2)
roc_BNB = round(roc_auc_score(y_test,predictions_BNB)*100,2)

print("Precision: ",precision_BNB,'%')
print("Recall score: ",recall_BNB,'%')
print("F1 Score:", f1_BNB)
print("ROC score: ",roc_BNB,'%')
# Out:
# accuracy_BNB: 79.82 %
#
# Confusion Matrix:
#  [[62 15]
#  [ 7 25]]
# Precision:  62.5 %
# Recall score:  78.12 %
# F1 Score: 0.69
# ROC score:  79.32 %

# %% [markdown]
# # AdaBoost

# %%
ABC = AdaBoostClassifier()
ABC.fit(X_train, y_train)
predictions_ABC = ABC.predict(X_test)

# Calculate accuracy_ABC
accuracy_ABC = accuracy_score(y_test, predictions_ABC)
print("accuracy_ABC:", round(accuracy_ABC*100, 2), "%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_ABC)
print("\nConfusion Matrix:\n", conf_matrix)

# precision, recall, f1, roc
precision_ABC = round(precision_score(y_test,predictions_ABC)*100, 2)
recall_ABC = round(recall_score(y_test,predictions_ABC)*100,2)
f1_ABC = round(f1_score(y_test,predictions_ABC)*1,2)
roc_ABC = round(roc_auc_score(y_test,predictions_ABC)*100,2)

print("Precision: ",precision_ABC,'%')
print("Recall score: ",recall_ABC,'%')
print("F1 Score:", f1_ABC)
print("ROC score: ",roc_ABC,'%')
# Out:
# accuracy_ABC: 91.74 %
#
# Confusion Matrix:
#  [[73  4]
#  [ 5 27]]
# Precision:  87.1 %
# Recall score:  84.38 %
# F1 Score: 0.86
# ROC score:  89.59 %

# %% [markdown]
# # List of models, accuracy, precision, recall, f1 score

# %%
models = np.array(['LogisticRegression', 'GaussianNB', 'DecisionTree', 'RandomForest', 'SVC', 'MultinomialNB', 'MLP', 'LinearSVC', 'KNN', 'GradientBoost', 'ExtraTrees', 'BernoulliNB', 'AdaBoost'])

accuracy = np.array([accuracy_LR,accuracy_GNB,accuracy_DTC,accuracy_RFC,accuracy_SVC,accuracy_MNB,accuracy_MLP,accuracy_LSVC,accuracy_KNN,accuracy_GBC,accuracy_ETC,accuracy_BNB,accuracy_ABC])

precision = np.array([precision_LR,precision_GNB,precision_DTC,precision_RFC,precision_SVC,precision_MNB,precision_MLP,precision_LSVC,precision_KNN,precision_GBC,precision_ETC,precision_BNB,precision_ABC])

recall = np.array([recall_LR,recall_GNB,recall_DTC,recall_RFC,recall_SVC,recall_MNB,recall_MLP,recall_LSVC,recall_KNN,recall_GBC,recall_ETC,recall_BNB,recall_ABC])

f1_score = np.array([f1_LR,f1_GNB,f1_DTC,f1_RFC,f1_SVC,f1_MNB,f1_MLP,f1_LSVC,f1_KNN,f1_GBC,f1_ETC,f1_BNB,f1_ABC])

roc_score = np.array([roc_LR,roc_GNB,roc_DTC,roc_RFC,roc_SVC,roc_MNB,roc_MLP,roc_LSVC,roc_KNN,roc_GBC,roc_ETC,roc_BNB,roc_ABC])

# %%
chart_dict = [{'Model':'LogisticRegression', 'Accuracy': accuracy_LR, 'Precision': precision_LR, 'Recall': recall_LR, 'f1_score': f1_LR, 'roc_score': roc_LR},
         {'Model':'GaussianNB', 'Accuracy': accuracy_GNB, 'Precision': precision_GNB, 'Recall': recall_GNB, 'f1_score': f1_GNB, 'roc_score': roc_GNB},
         {'Model':'DecisionTree', 'Accuracy': accuracy_DTC, 'Precision': precision_DTC, 'Recall': recall_DTC, 'f1_score': f1_DTC, 'roc_score': roc_DTC},
         {'Model':'RandomForest', 'Accuracy': accuracy_RFC, 'Precision': precision_RFC, 'Recall': recall_RFC, 'f1_score': f1_RFC, 'roc_score': roc_RFC},
         {'Model':'SVC', 'Accuracy': accuracy_SVC, 'Precision': precision_SVC, 'Recall': recall_SVC, 'f1_score': f1_SVC, 'roc_score': roc_SVC},
         {'Model':'MultinomialNB', 'Accuracy': accuracy_MNB, 'Precision': precision_MNB, 'Recall': recall_MNB, 'f1_score': f1_MNB, 'roc_score': roc_MNB},
         {'Model':'MLPClassifier', 'Accuracy': accuracy_MLP, 'Precision': precision_MLP, 'Recall': recall_MLP, 'f1_score': f1_MLP, 'roc_score': roc_MLP},
         {'Model':'LinearSVC', 'Accuracy': accuracy_LSVC, 'Precision': precision_LSVC, 'Recall': recall_LSVC, 'f1_score': f1_LSVC, 'roc_score': roc_LSVC},
         {'Model':'KNN', 'Accuracy': accuracy_KNN, 'Precision': precision_KNN, 'Recall': recall_KNN, 'f1_score': f1_KNN, 'roc_score': roc_KNN},
         {'Model':'GradientBoost', 'Accuracy': accuracy_GBC, 'Precision': precision_GBC, 'Recall': recall_GBC, 'f1_score': f1_GBC, 'roc_score': roc_GBC},
         {'Model':'ExtraTrees', 'Accuracy': accuracy_ETC, 'Precision': precision_ETC, 'Recall': recall_ETC, 'f1_score': f1_ETC, 'roc_score': roc_ETC},
         {'Model':'BernoulliNB', 'Accuracy': accuracy_BNB, 'Precision': precision_BNB, 'Recall': recall_BNB, 'f1_score': f1_BNB, 'roc_score': roc_BNB},
         {'Model':'AdaBoostClassifier', 'Accuracy': accuracy_ABC, 'Precision': precision_ABC, 'Recall': recall_ABC, 'f1_score': f1_ABC, 'roc_score': roc_ABC}]

chart_dataframe = pd.DataFrame(chart_dict)

print(chart_dataframe)
# Out:
#                  Model  Accuracy  Precision  Recall  f1_score  roc_score
# 0   LogisticRegression  0.844037      75.86   68.75      0.72      79.83
# 1           GaussianNB  0.807339      62.79   84.38      0.72      81.80
# 2         DecisionTree  0.834862      70.59   75.00      0.73      81.01
# 3         RandomForest  0.935780      96.30   81.25      0.88      89.98
# 4                  SVC  0.715596     100.00    3.12      0.06      51.56
# 5        MultinomialNB  0.339450      27.27   75.00      0.40      45.94
# 6        MLPClassifier  0.724771      53.57   46.88      0.50      65.00
# 7            LinearSVC  0.853211      80.77   65.62      0.72      79.57
# 8                  KNN  0.614679      33.33   31.25      0.32      52.64
# 9        GradientBoost  0.917431      87.10   84.38      0.86      89.59
# 10          ExtraTrees  0.908257      82.35   87.50      0.85      89.85
# 11         BernoulliNB  0.798165      62.50   78.12      0.69      79.32
# ...

# %% [markdown]
# # Accuracy comparison

# %%
plt.figure(figsize=(20, 10))
bars = plt.bar(models, accuracy, color='teal', width=0.5)
plt.ylim(0.5, 1)
plt.grid(True, axis='y')

# Add data labels (accuracy values) above each bar
for bar, acc in zip(bars, accuracy):
    height = bar.get_height()
    plt.annotate(f'{acc:.2f}',  # Format accuracy to two decimal places
                 xy=(bar.get_x() + bar.get_width() / 2, height),
                 xytext=(0, 3),  # Offset label above the bar
                 textcoords="offset points",
                 ha='center', va='bottom', fontsize=10)

plt.show()

# %% [markdown]
# # ROC Curves

# %%
LR_fpr, LR_tpr, threshold = roc_curve(y_test, predictions_LR)
LR_auc = auc(LR_fpr, LR_tpr)
plt.figure(figsize=(4, 4), dpi=100)
plt.plot(LR_fpr, LR_tpr, color='darkorange', lw=2, label=f'ROC curve (area = {LR_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Logistic Regression')
plt.legend(loc="lower right")
plt.show()

# %%
GNB_fpr, GNB_tpr, threshold = roc_curve(y_test, predictions_GNB)
GNB_auc = auc(GNB_fpr, GNB_tpr)
plt.figure(figsize=(4, 4), dpi=100)
plt.plot(GNB_fpr, GNB_tpr, color='darkorange', lw=2, label=f'ROC curve (area = {GNB_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Gaussian NB')
plt.legend(loc="lower right")
plt.show()

# %%
DTC_fpr, DTC_tpr, threshold = roc_curve(y_test, predictions_DTC)
DTC_auc = auc(DTC_fpr, DTC_tpr)
plt.figure(figsize=(4, 4), dpi=100)
plt.plot(DTC_fpr, DTC_tpr, color='darkorange', lw=2, label=f'ROC curve (area = {DTC_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('DecisionTreeClassifier')
plt.legend(loc="lower right")
plt.show()

# %%
RFC_fpr, RFC_tpr, threshold = roc_curve(y_test, predictions_RFC)
RFC_auc = auc(RFC_fpr, RFC_tpr)
plt.figure(figsize=(4, 4), dpi=100)
plt.plot(RFC_fpr, RFC_tpr, color='darkorange', lw=2, label=f'ROC curve (area = {RFC_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('RandomForestClassifier')
plt.legend(loc="lower right")
plt.show()

# %%
SVC_fpr, SVC_tpr, threshold = roc_curve(y_test, predictions_SVC)
SVC_auc = auc(SVC_fpr, SVC_tpr)
plt.figure(figsize=(4, 4), dpi=100)
plt.plot(SVC_fpr, SVC_tpr, color='darkorange', lw=2, label=f'ROC curve (area = {SVC_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Support Vector Classifier')
plt.legend(loc="lower right")
plt.show()

# %%
MNB_fpr, MNB_tpr, threshold = roc_curve(y_test, predictions_MNB)
MNB_auc = auc(MNB_fpr, MNB_tpr)
plt.figure(figsize=(4, 4), dpi=100)
plt.plot(MNB_fpr, MNB_tpr, color='darkorange', lw=2, label=f'ROC curve (area = {MNB_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multinomial NB')
plt.legend(loc="lower right")
plt.show()

# %%
MLP_fpr, MLP_tpr, threshold = roc_curve(y_test, predictions_MLP)
MLP_auc = auc(MLP_fpr, MLP_tpr)
plt.figure(figsize=(4, 4), dpi=100)
plt.plot(MLP_fpr, MLP_tpr, color='darkorange', lw=2, label=f'ROC curve (area = {MLP_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('MultiLayerPerceptiop')
plt.legend(loc="lower right")
plt.show()

# %%
LSVC_fpr, LSVC_tpr, threshold = roc_curve(y_test, predictions_LSVC)
LSVC_auc = auc(LSVC_fpr, LSVC_tpr)
plt.figure(figsize=(4, 4), dpi=100)
plt.plot(LSVC_fpr, LSVC_tpr, color='darkorange', lw=2, label=f'ROC curve (area = {LSVC_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Linear SVC')
plt.legend(loc="lower right")
plt.show()

# %%
KNN_fpr, KNN_tpr, threshold = roc_curve(y_test, predictions_KNN)
KNN_auc = auc(KNN_fpr, KNN_tpr)
plt.figure(figsize=(4, 4), dpi=100)
plt.plot(KNN_fpr, KNN_tpr, color='darkorange', lw=2, label=f'ROC curve (area = {KNN_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('KNN')
plt.legend(loc="lower right")
plt.show()

# %%
GBC_fpr, GBC_tpr, threshold = roc_curve(y_test, predictions_GBC)
GBC_auc = auc(GBC_fpr, GBC_tpr)
plt.figure(figsize=(4, 4), dpi=100)
plt.plot(GBC_fpr, GBC_tpr, color='darkorange', lw=2, label=f'ROC curve (area = {GBC_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('GradientBoosting')
plt.legend(loc="lower right")
plt.show()

# %%
ETC_fpr, ETC_tpr, threshold = roc_curve(y_test, predictions_ETC)
ETC_auc = auc(ETC_fpr, ETC_tpr)
plt.figure(figsize=(4, 4), dpi=100)
plt.plot(ETC_fpr, ETC_tpr, color='darkorange', lw=2, label=f'ROC curve (area = {ETC_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ExtraTree')
plt.legend(loc="lower right")
plt.show()

# %%
BNB_fpr, BNB_tpr, threshold = roc_curve(y_test, predictions_BNB)
BNB_auc = auc(BNB_fpr, BNB_tpr)
plt.figure(figsize=(4, 4), dpi=100)
plt.plot(BNB_fpr, BNB_tpr, color='darkorange', lw=2, label=f'ROC curve (area = {BNB_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Bernoulli NB')
plt.legend(loc="lower right")
plt.show()

# %%
ABC_fpr, ABC_tpr, threshold = roc_curve(y_test, predictions_ABC)
ABC_auc = auc(ABC_fpr, ABC_tpr)
plt.figure(figsize=(4, 4), dpi=100)
plt.plot(ABC_fpr, ABC_tpr, color='darkorange', lw=2, label=f'ROC curve (area = {ABC_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AdaBoosting')
plt.legend(loc="lower right")
plt.show()
